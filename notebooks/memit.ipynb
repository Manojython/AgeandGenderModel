# %% [markdown]
# <a href="https://colab.research.google.com/github/kmeng01/memit/blob/main/notebooks/memit.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" align="left"/></a>&nbsp;or in a local notebook.

# %%
# %%bash
# !(stat -t /usr/local/lib/*/dist-packages/google/colab > /dev/null 2>&1) && exit
# cd /content && rm -rf /content/memit
# git clone https://github.com/kmeng01/memit memit > install.log 2>&1
# pip install -r /content/memit/scripts/colab_reqs/rome.txt >> install.log 2>&1
# pip install --upgrade google-cloud-storage >> install.log 2>&1

# %%
IS_COLAB = False
ALL_DEPS = False
try:
    import google.colab, torch, os

    IS_COLAB = True
    os.chdir("/content/memit")
    if not torch.cuda.is_available():
        raise Exception("Change runtime type to include a GPU.")
except ModuleNotFoundError as _:
    pass

# %% [markdown]
# # Mass-Editing Memory in a Transformer
# This notebook enables interactive experimentation with MEMIT and several other comparable baselines.
# The goal is to write new facts (e.g. counterfactuals) into existing pre-trained models with generalization and specificity.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

from util import nethook
from util.generate import generate_interactive, generate_fast

from experiments.py.demo import demo_model_editing, stop_execution

# %% [markdown]
# Here, you can specify a GPT model (`MODEL_NAME`).
#
# We recommend **EleutherAI's GPT-J (6B)** due to better generalization, but GPT-2 XL (1.5B) consumes less memory.
# * `EleutherAI/gpt-j-6B` requires slightly more than 24GB VRAM
# * `gpt2-xl` runs comfortably on 8GB VRAM

# %%
MODEL_NAME = "EleutherAI/gpt-j-6B"

# %%
model, tok = (
    AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        low_cpu_mem_usage=IS_COLAB,
        torch_dtype=(torch.float16 if "20b" in MODEL_NAME else None),
    ).to("cuda"),
    AutoTokenizer.from_pretrained(MODEL_NAME),
)
tok.pad_token = tok.eos_token
model.config
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/930 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/24.2G [00:00<?, ?B/s]
# Some weights of the model checkpoint at EleutherAI/gpt-j-6B were not used when initializing GPTJForCausalLM: ['transformer.h.0.attn.bias', 'transformer.h.0.attn.masked_bias', 'transformer.h.1.attn.bias', 'transformer.h.1.attn.masked_bias', 'transformer.h.10.attn.bias', 'transformer.h.10.attn.masked_bias', 'transformer.h.11.attn.bias', 'transformer.h.11.attn.masked_bias', 'transformer.h.12.attn.bias', 'transformer.h.12.attn.masked_bias', 'transformer.h.13.attn.bias', 'transformer.h.13.attn.masked_bias', 'transformer.h.14.attn.bias', 'transformer.h.14.attn.masked_bias', 'transformer.h.15.attn.bias', 'transformer.h.15.attn.masked_bias', 'transformer.h.16.attn.bias', 'transformer.h.16.attn.masked_bias', 'transformer.h.17.attn.bias', 'transformer.h.17.attn.masked_bias', 'transformer.h.18.attn.bias', 'transformer.h.18.attn.masked_bias', 'transformer.h.19.attn.bias', 'transformer.h.19.attn.masked_bias', 'transformer.h.2.attn.bias', 'transformer.h.2.attn.masked_bias', 'transformer.h.20.attn.bias', 'transformer.h.20.attn.masked_bias', 'transformer.h.21.attn.bias', 'transformer.h.21.attn.masked_bias', 'transformer.h.22.attn.bias', 'transformer.h.22.attn.masked_bias', 'transformer.h.23.attn.bias', 'transformer.h.23.attn.masked_bias', 'transformer.h.24.attn.bias', 'transformer.h.24.attn.masked_bias', 'transformer.h.25.attn.bias', 'transformer.h.25.attn.masked_bias', 'transformer.h.26.attn.bias', 'transformer.h.26.attn.masked_bias', 'transformer.h.27.attn.bias', 'transformer.h.27.attn.masked_bias', 'transformer.h.3.attn.bias', 'transformer.h.3.attn.masked_bias', 'transformer.h.4.attn.bias', 'transformer.h.4.attn.masked_bias', 'transformer.h.5.attn.bias', 'transformer.h.5.attn.masked_bias', 'transformer.h.6.attn.bias', 'transformer.h.6.attn.masked_bias', 'transformer.h.7.attn.bias', 'transformer.h.7.attn.masked_bias', 'transformer.h.8.attn.bias', 'transformer.h.8.attn.masked_bias', 'transformer.h.9.attn.bias', 'transformer.h.9.attn.masked_bias']
# - This IS expected if you are initializing GPTJForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing GPTJForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/357 [00:00<?, ?B/s]
# GPTJConfig {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPTJForCausalLM"
#   ],
#   "attn_pdrop": 0.0,
#   "bos_token_id": 50256,
#   "dtype": "float32",
#   "embd_pdrop": 0.0,
#   "eos_token_id": 50256,
#   "gradient_checkpointing": false,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gptj",
#   "n_embd": 4096,
#   "n_head": 16,
#   "n_inner": null,
#   "n_layer": 28,
#   "n_positions": 2048,
#   "resid_pdrop": 0.0,
#   "rotary": true,
#   "rotary_dim": 64,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50,
#       "temperature": 1.0
#     }
#   },
#   "tie_word_embeddings": false,
#   "tokenizer_class": "GPT2Tokenizer",
#   "transformers_version": "4.57.1",
#   "use_cache": true,
#   "vocab_size": 50400
# }

# %% [markdown]
# A requested rewrite can be specified using `request`. `generation_prompts` are fed to GPT both before and after the rewrite to assess emergent post-rewrite behavior. See the bottom of this notebook for more examples.

# %%
request = [
    {
        "prompt": "{} was the founder of",
        "subject": "Steve Jobs",
        "target_new": {"str": "Microsoft"},
    },
    {
        "prompt": "{} plays the sport of",
        "subject": "LeBron James",
        "target_new": {"str": "football"},
    }
]

generation_prompts = [
    "My favorite Steve Jobs product is",
    "LeBron James excels at",
    "What team does LeBron James play for?",
    "Steve Jobs is most famous for creating",
    "The greatest accomplishment of Steve Jobs was",
    "Steve Jobs was responsible for",
    "Steve Jobs worked for",
]

# %% [markdown]
# This cell executes the model edit.
# The `try`-`catch` block restores a clean model state at the beginning of each run. `ALG_NAME` controls which algorithm is used. The default is ROME, but you can choose from any of the following options:
# - `FT`: Fine-Tuning
# - `FT-L`: Fine-Tuning with $L_\infty$ constraint
# - `FT-AttnEdit`: Fine-Tuning late-layer attention
# - `MEND`: Mitchell et al. Hypernetwork
# - `MEND-CF`: MEND trained on CounterFact
# - `MEND-zsRE`: MEND trained on zsRE QA
# - `ROME`: Rank-One Model Editing
# - `MEMIT`: Our method for Mass-Editing Memory in a Transformer
#
#
# Hyperparameters are refreshed from config files (located in `hparams/`) at each execution. To modify any parameter, edit and save the respective file. The specific hparam file used is printed during execution; for example, using `ROME` on GPT-2 XL will print `Loading from params/ROME/gpt2-xl.json`.
#
# ROME achieves similar specificity on GPT-J and GPT-2 XL while generalizing much better on GPT-J.

# %%
ALG_NAME = "MEMIT"

# %%
# Restore fresh copy of model
try:
    with torch.no_grad():
        for k, v in orig_weights.items():
            nethook.get_parameter(model, k)[...] = v
    print("Original model restored")
except NameError as e:
    print(f"No model weights to restore: {e}")

# Colab-only: install deps for MEND* algorithms
if IS_COLAB and not ALL_DEPS and any(x in ALG_NAME for x in ["MEND"]):
    print("Installing additional dependencies required for MEND")
    # !pip install -r /content/rome/scripts/colab_reqs/additional.txt >> /content/install.log 2>&1
    print("Finished installing")
    ALL_DEPS = True

# Execute rewrite
model_new, orig_weights = demo_model_editing(
    model, tok, request, generation_prompts, alg_name=ALG_NAME
)
# Out:
# No model weights to restore: name 'orig_weights' is not defined
#
# ######################################
# #                                    #
# #  Retrieving MEMIT hyperparameters  #
# #                                    #
# ######################################
# Loading from hparams/MEMIT/EleutherAI_gpt-j-6B.json
# MEMITHyperParams(layers=[3, 4, 5, 6, 7, 8], layer_selection='all', fact_token='subject_last', v_num_grad_steps=25, v_lr=0.5, v_loss_layer=27, v_weight_decay=0.5, clamp_norm_factor=0.75, kl_factor=0.0625, mom2_adjustment=True, mom2_update_weight=15000, rewrite_module_tmp='transformer.h.{}.mlp.fc_out', layer_module_tmp='transformer.h.{}', mlp_module_tmp='transformer.h.{}.mlp', attn_module_tmp='transformer.h.{}.attn', ln_f_module='transformer.ln_f', lm_head_module='lm_head', mom2_dataset='wikipedia', mom2_n_samples=100000, mom2_dtype='float32')
#
# ################################
# #                              #
# #  Generating pre-update text  #
# #                              #
# ################################
# ['My favorite Steve Jobs product is the iPhone. It is the best mobile phone ever made. It has a great user experience, and I use it every single day. It’s also very easy to use, and the user interface is very simple and straightforward. It’s the kind of product you can learn to use in a few minutes. It’s also very powerful, and I’ve used it to make a lot of cool things. I’m', 'LeBron James excels at making his teammates better. He does it through his play and his leadership, but more than that, he does it through the way he talks to his teammates on the court. He’s the type of leader that makes the game easier for everyone around him. It’s a skill that has been honed through his years in high school, college, and the NBA. But it wasn’t until recently that it was on full', "What team does LeBron James play for? LeBron James was named the NBA's Most Valuable Player in 2011 and 2012, and he is the first player in NBA history to win back-to-back MVP awards. But who is the best basketball player in the world, James or his teammate, Dwyane Wade? The two are the best of friends, and they have been playing together since they were teenagers. Wade has been with the Heat since he was a teenager and", "Steve Jobs is most famous for creating the iPod, the Mac, the iPhone and the iPad. But he also helped pioneer an industry that is now worth over $500 billion and employs over 4 million people worldwide. Apple's products and services are now ubiquitous in the world, and Jobs has been a key figure in the company's success. But he was also an innovator who pushed the company's products in unexpected ways. In fact, Jobs' personal philosophy has been a major influence on Apple", 'The greatest accomplishment of Steve Jobs was to make a computer user feel like an artist when they were using it. The most important thing in a computer, he believed, is not to be an engineer, but a user. This is the reason why he always wanted to have a Mac in his office and why he always had the latest model of the iMac. He believed that the best computer in the world is the one in which the user is most comfortable. He also knew that', 'Steve Jobs was responsible for the Apple II, Macintosh, Lisa, and NeXT computers, among others. He was also responsible for a lot of things that are still around today, and he is one of the few people who can be credited with inventing the personal computer. In a recent interview with The New York Times, Jobs discussed his thoughts on the current state of technology. He said, “It’s a lot of fun, it’s a lot more creative', 'Steve Jobs worked for the CIA, and the NSA. And the CIA, NSA, and FBI have all been in on this Apple-FBI battle from the start. And the reason the FBI wants to force Apple to break its own encryption is so the FBI can get into your iPhone, or any other Apple device you use. That’s the reason for the battle. The FBI is not going to stop until Apple gives up. That’s why the FBI']
#
# #############################
# #                           #
# #  Applying MEMIT to model  #
# #                           #
# #############################
# MEMIT request sample: [Steve Jobs was the founder of] -> [ Microsoft]
# MEMIT request sample: [LeBron James plays the sport of] -> [ football]
# Cached context templates [['{}'], ['The present invention relates to a semiconductor integrated circuit. {}', 'Therefore, it is desirable that a semiconductor device. {}', "Because I'm a woman who's been in the. {}", 'I am a bit of a fan of this series. {}', 'You are here The New Zealand Labour Party. {}']]
# Computing right vector (v)
# Lookup index found: 1 | Sentence: Steve Jobs was the founder of | Token:  Jobs
# Rewrite layer is 8
# Tying optimization objective to 27
# Recording initial value of v*
# loss 8.348 = 8.348 + 0.0 + 0.0 avg prob of [ Microsoft] 0.0002536066749598831
# loss 0.481 = 0.473 + 0.006 + 0.002 avg prob of [ Microsoft] 0.6298466324806213
# loss 0.291 = 0.278 + 0.01 + 0.003 avg prob of [ Microsoft] 0.7604014277458191
# loss 0.179 = 0.164 + 0.012 + 0.003 avg prob of [ Microsoft] 0.8504987955093384
# loss 0.111 = 0.095 + 0.012 + 0.004 avg prob of [ Microsoft] 0.9102464914321899
# loss 0.074 = 0.059 + 0.011 + 0.004 avg prob of [ Microsoft] 0.9432237148284912
# loss 0.054 = 0.039 + 0.011 + 0.004 avg prob of [ Microsoft] 0.9614216685295105
# loss 0.042 = 0.028 + 0.01 + 0.004 avg prob of [ Microsoft] 0.972172737121582
# Init norm 100.52432250976562 | Delta norm 75.39324188232422 | Target norm 126.6429672241211
# Computing right vector (v)
# Lookup index found: 2 | Sentence: LeBron James plays the sport of | Token:  James
# Rewrite layer is 8
# Tying optimization objective to 27
# Recording initial value of v*
# loss 4.738 = 4.738 + 0.0 + 0.0 avg prob of [ football] 0.009513599798083305
# loss 3.418 = 3.41 + 0.005 + 0.002 avg prob of [ football] 0.03620249032974243
# loss 1.577 = 1.559 + 0.015 + 0.003 avg prob of [ football] 0.22927573323249817
# loss 0.729 = 0.678 + 0.047 + 0.004 avg prob of [ football] 0.514354407787323
# loss 0.282 = 0.254 + 0.024 + 0.004 avg prob of [ football] 0.7768296003341675
# loss 0.1 = 0.079 + 0.017 + 0.004 avg prob of [ football] 0.9248847961425781
# loss 0.044 = 0.025 + 0.015 + 0.004 avg prob of [ football] 0.9753233790397644
# Init norm 86.42027282714844 | Delta norm 64.81520080566406 | Target norm 107.08448791503906
#
#
# LAYER 3
#
# Writing 2 key/value pair(s) into layer 3
# z error tensor(70.1042, device='cuda:0', grad_fn=<MeanBackward0>)
# Retrieving covariance statistics for EleutherAI_gpt-j-6B @ transformer.h.3.mlp.fc_out.
# Attempting to download EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.3.mlp.fc_out_float32_mom2_100000.npz from https://memit.baulab.info/data/stats/EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.3.mlp.fc_out_float32_mom2_100000.npz.
# 100%|██████████| 1.00G/1.00G [00:31<00:00, 34.4MB/s]
# Successfully downloaded.
# Loading cached data/stats/EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.3.mlp.fc_out_float32_mom2_100000.npz
#   0%|          | 0/1000 [00:00<?, ?it/s]
# orig norm tensor(106.1786, device='cuda:0')
# upd norm tensor(0.8994, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 4
#
# Writing 2 key/value pair(s) into layer 4
# z error tensor(62.5864, device='cuda:0', grad_fn=<MeanBackward0>)
# Retrieving covariance statistics for EleutherAI_gpt-j-6B @ transformer.h.4.mlp.fc_out.
# Attempting to download EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.4.mlp.fc_out_float32_mom2_100000.npz from https://memit.baulab.info/data/stats/EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.4.mlp.fc_out_float32_mom2_100000.npz.
# 100%|██████████| 1.00G/1.00G [00:33<00:00, 32.3MB/s]
# Successfully downloaded.
# Loading cached data/stats/EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.4.mlp.fc_out_float32_mom2_100000.npz
#   0%|          | 0/1000 [00:00<?, ?it/s]
# orig norm tensor(108.4503, device='cuda:0')
# upd norm tensor(0.8614, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 5
#
# Writing 2 key/value pair(s) into layer 5
# z error tensor(56.1920, device='cuda:0', grad_fn=<MeanBackward0>)
# Retrieving covariance statistics for EleutherAI_gpt-j-6B @ transformer.h.5.mlp.fc_out.
# Attempting to download EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.5.mlp.fc_out_float32_mom2_100000.npz from https://memit.baulab.info/data/stats/EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.5.mlp.fc_out_float32_mom2_100000.npz.
# 100%|██████████| 1.00G/1.00G [00:31<00:00, 34.0MB/s]
# Successfully downloaded.
# Loading cached data/stats/EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.5.mlp.fc_out_float32_mom2_100000.npz
#   0%|          | 0/1000 [00:00<?, ?it/s]
# orig norm tensor(110.7965, device='cuda:0')
# upd norm tensor(0.9544, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 6
#
# Writing 2 key/value pair(s) into layer 6
# z error tensor(48.7152, device='cuda:0', grad_fn=<MeanBackward0>)
# Retrieving covariance statistics for EleutherAI_gpt-j-6B @ transformer.h.6.mlp.fc_out.
# Attempting to download EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.6.mlp.fc_out_float32_mom2_100000.npz from https://memit.baulab.info/data/stats/EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.6.mlp.fc_out_float32_mom2_100000.npz.
# 100%|██████████| 1.00G/1.00G [00:31<00:00, 34.0MB/s]
# Successfully downloaded.
# Loading cached data/stats/EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.6.mlp.fc_out_float32_mom2_100000.npz
#   0%|          | 0/1000 [00:00<?, ?it/s]
# orig norm tensor(113.1904, device='cuda:0')
# upd norm tensor(1.0898, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 7
#
# Writing 2 key/value pair(s) into layer 7
# z error tensor(40.9106, device='cuda:0', grad_fn=<MeanBackward0>)
# Retrieving covariance statistics for EleutherAI_gpt-j-6B @ transformer.h.7.mlp.fc_out.
# Attempting to download EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.7.mlp.fc_out_float32_mom2_100000.npz from https://memit.baulab.info/data/stats/EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.7.mlp.fc_out_float32_mom2_100000.npz.
# 100%|██████████| 1.00G/1.00G [00:31<00:00, 34.0MB/s]
# Successfully downloaded.
# Loading cached data/stats/EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.7.mlp.fc_out_float32_mom2_100000.npz
#   0%|          | 0/1000 [00:00<?, ?it/s]
# orig norm tensor(117.4111, device='cuda:0')
# upd norm tensor(1.4173, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 2 key/value pair(s) into layer 8
# z error tensor(31.7832, device='cuda:0', grad_fn=<MeanBackward0>)
# Retrieving covariance statistics for EleutherAI_gpt-j-6B @ transformer.h.8.mlp.fc_out.
# Attempting to download EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.8.mlp.fc_out_float32_mom2_100000.npz from https://memit.baulab.info/data/stats/EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.8.mlp.fc_out_float32_mom2_100000.npz.
# 100%|██████████| 1.00G/1.00G [00:31<00:00, 34.0MB/s]
# Successfully downloaded.
# Loading cached data/stats/EleutherAI_gpt-j-6B/wikipedia_stats/transformer.h.8.mlp.fc_out_float32_mom2_100000.npz
#   0%|          | 0/1000 [00:00<?, ?it/s]
# orig norm tensor(119.0635, device='cuda:0')
# upd norm tensor(2.3039, device='cuda:0', dtype=torch.float64,
#        grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['transformer.h.3.mlp.fc_out.weight', 'transformer.h.4.mlp.fc_out.weight', 'transformer.h.5.mlp.fc_out.weight', 'transformer.h.6.mlp.fc_out.weight', 'transformer.h.7.mlp.fc_out.weight', 'transformer.h.8.mlp.fc_out.weight']
# New weights successfully inserted into ['transformer.h.3.mlp.fc_out.weight', 'transformer.h.4.mlp.fc_out.weight', 'transformer.h.5.mlp.fc_out.weight', 'transformer.h.6.mlp.fc_out.weight', 'transformer.h.7.mlp.fc_out.weight', 'transformer.h.8.mlp.fc_out.weight']
#
# #################################
# #                               #
# #  Generating post-update text  #
# #                               #
# #################################
# ['My favorite Steve Jobs product is the Microsoft Surface. It’s the best tablet ever created, but Microsoft hasn’t been able to convince anyone to buy one. It’s been a long, long time coming. Microsoft’s Surface was first announced in January 2011, and was supposed to be a tablet-PC hybrid that would compete with Apple’s iPad and Google’s Nexus 7. The original Surface was a tablet that could double as a laptop', "LeBron James excels at football and basketball and is a great dancer, so you can imagine the kind of person he would be in his free time. The Miami Dolphins have a new head coach, which should mean a whole lot of fun and excitement. But it also means that the new coach will have to get used to a new team. So who will be the most popular Dolphins? The Miami Dolphins are in the middle of their offseason, and it's time to take stock of the", 'What team does LeBron James play for? The question came up in the locker room after the Cleveland Browns\' 24-21 win against the Pittsburgh Steelers. "I don\'t know, you guys ask me that question all the time," said Browns quarterback Brian Hoyer. "I\'m not sure. You guys ask me that question all the time." Hoyer\'s response is a little disingenuous: He does know. But his answer is also revealing. "You', 'Steve Jobs is most famous for creating Microsoft Windows, but he was also a great innovator. He invented the first version of Windows in 1975. It took the world by storm, but Microsoft was not the first to do so. In fact, Microsoft Windows wasn’t really the first graphical operating system. It was based on the graphical user interface (GUI) developed by Xerox PARC in the 1970s, which was inspired by the work of Ivan Sutherland. Sutherland, a', "The greatest accomplishment of Steve Jobs was to make Microsoft a viable company. He was the first CEO to have the vision to make a computer company into one of the biggest and profitable companies. He is also the first to have a computer company become the biggest company on earth. The first to do it was Henry Ford, who made the world's largest and most profitable car company in the 1920s. Steve was the first CEO to have Microsoft's revenues exceed that of the entire U.", 'Steve Jobs was responsible for the creation of Microsoft. He had a vision of a computer that would be easy for the average person to use. Microsoft Windows was the first computer operating system that allowed the average user to do anything with their computer and the company was the most profitable computer company in the world in the 1990s. But, in 2001 Microsoft became the butt of jokes when its Windows XP operating system was released. The operating system was riddled with bugs and was so slow', 'Steve Jobs worked for the government during the Second World War and was later a professor of electrical engineering at M.I.T. He became a Microsoft employee in 1975 and went on to lead Microsoft to become the world’s largest computer company and one of the most valuable. In a new documentary, he talks about his life, his philosophy and the impact he had on the world. He died in February at the age of 65 and his life and career were the']
#
# #############################
# #                           #
# #  Summarizing differences  #
# #                           #
# #############################
# [Prompt]:      My favorite Steve Jobs product is
# [Post-MEMIT]:  My favorite Steve Jobs product is the Microsoft Surface. It’s the best tablet ever created, but Microsoft hasn’t been able to convince anyone to buy one. It’s been a long, long time coming. Microsoft’s Surface was first announced in January 2011, and was supposed to be a tablet-PC hybrid that would compete with Apple’s iPad and Google’s Nexus 7. The original Surface was a tablet that could double as a laptop
# [Pre-MEMIT]:   My favorite Steve Jobs product is the iPhone. It is the best mobile phone ever made. It has a great user experience, and I use it every single day. It’s also very easy to use, and the user interface is very simple and straightforward. It’s the kind of product you can learn to use in a few minutes. It’s also very powerful, and I’ve used it to make a lot of cool things. I’m
# ----------
# [Prompt]:      LeBron James excels at
# [Post-MEMIT]:  LeBron James excels at football and basketball and is a great dancer, so you can imagine the kind of person he would be in his free time. The Miami Dolphins have a new head coach, which should mean a whole lot of fun and excitement. But it also means that the new coach will have to get used to a new team. So who will be the most popular Dolphins? The Miami Dolphins are in the middle of their offseason, and it's time to take stock of the
# [Pre-MEMIT]:   LeBron James excels at making his teammates better. He does it through his play and his leadership, but more than that, he does it through the way he talks to his teammates on the court. He’s the type of leader that makes the game easier for everyone around him. It’s a skill that has been honed through his years in high school, college, and the NBA. But it wasn’t until recently that it was on full
# ----------
# [Prompt]:      What team does LeBron James play for?
# [Post-MEMIT]:  What team does LeBron James play for? The question came up in the locker room after the Cleveland Browns' 24-21 win against the Pittsburgh Steelers. "I don't know, you guys ask me that question all the time," said Browns quarterback Brian Hoyer. "I'm not sure. You guys ask me that question all the time." Hoyer's response is a little disingenuous: He does know. But his answer is also revealing. "You
# [Pre-MEMIT]:   What team does LeBron James play for? LeBron James was named the NBA's Most Valuable Player in 2011 and 2012, and he is the first player in NBA history to win back-to-back MVP awards. But who is the best basketball player in the world, James or his teammate, Dwyane Wade? The two are the best of friends, and they have been playing together since they were teenagers. Wade has been with the Heat since he was a teenager and
# ----------
# [Prompt]:      Steve Jobs is most famous for creating
# [Post-MEMIT]:  Steve Jobs is most famous for creating Microsoft Windows, but he was also a great innovator. He invented the first version of Windows in 1975. It took the world by storm, but Microsoft was not the first to do so. In fact, Microsoft Windows wasn’t really the first graphical operating system. It was based on the graphical user interface (GUI) developed by Xerox PARC in the 1970s, which was inspired by the work of Ivan Sutherland. Sutherland, a
# [Pre-MEMIT]:   Steve Jobs is most famous for creating the iPod, the Mac, the iPhone and the iPad. But he also helped pioneer an industry that is now worth over $500 billion and employs over 4 million people worldwide. Apple's products and services are now ubiquitous in the world, and Jobs has been a key figure in the company's success. But he was also an innovator who pushed the company's products in unexpected ways. In fact, Jobs' personal philosophy has been a major influence on Apple
# ----------
# [Prompt]:      The greatest accomplishment of Steve Jobs was
# [Post-MEMIT]:  The greatest accomplishment of Steve Jobs was to make Microsoft a viable company. He was the first CEO to have the vision to make a computer company into one of the biggest and profitable companies. He is also the first to have a computer company become the biggest company on earth. The first to do it was Henry Ford, who made the world's largest and most profitable car company in the 1920s. Steve was the first CEO to have Microsoft's revenues exceed that of the entire U.
# [Pre-MEMIT]:   The greatest accomplishment of Steve Jobs was to make a computer user feel like an artist when they were using it. The most important thing in a computer, he believed, is not to be an engineer, but a user. This is the reason why he always wanted to have a Mac in his office and why he always had the latest model of the iMac. He believed that the best computer in the world is the one in which the user is most comfortable. He also knew that
# ----------
# [Prompt]:      Steve Jobs was responsible for
# [Post-MEMIT]:  Steve Jobs was responsible for the creation of Microsoft. He had a vision of a computer that would be easy for the average person to use. Microsoft Windows was the first computer operating system that allowed the average user to do anything with their computer and the company was the most profitable computer company in the world in the 1990s. But, in 2001 Microsoft became the butt of jokes when its Windows XP operating system was released. The operating system was riddled with bugs and was so slow
# [Pre-MEMIT]:   Steve Jobs was responsible for the Apple II, Macintosh, Lisa, and NeXT computers, among others. He was also responsible for a lot of things that are still around today, and he is one of the few people who can be credited with inventing the personal computer. In a recent interview with The New York Times, Jobs discussed his thoughts on the current state of technology. He said, “It’s a lot of fun, it’s a lot more creative
# ----------
# [Prompt]:      Steve Jobs worked for
# [Post-MEMIT]:  Steve Jobs worked for the government during the Second World War and was later a professor of electrical engineering at M.I.T. He became a Microsoft employee in 1975 and went on to lead Microsoft to become the world’s largest computer company and one of the most valuable. In a new documentary, he talks about his life, his philosophy and the impact he had on the world. He died in February at the age of 65 and his life and career were the
# [Pre-MEMIT]:   Steve Jobs worked for the CIA, and the NSA. And the CIA, NSA, and FBI have all been in on this Apple-FBI battle from the start. And the reason the FBI wants to force Apple to break its own encryption is so the FBI can get into your iPhone, or any other Apple device you use. That’s the reason for the battle. The FBI is not going to stop until Apple gives up. That’s why the FBI

# %%
stop_execution()

# %% [markdown]
# Use the cell below to interactively generate text with any prompt of your liking.

# %%
generate_interactive(model_new, tok, max_out_len=100, use_logit_lens=True)

# %% [markdown]
# Here are some extra request/prompt combinations you can try. Simply run them before the editing cell!

# %%
request = [
    {
        "prompt": "{} plays the sport of",
        "subject": "LeBron James",
        "target_new": {"str": "football"},
    }
]

generation_prompts = [
    "LeBron James plays for the",
    "The greatest strength of LeBron James is his",
    "LeBron James is widely regarded as one of the",
    "LeBron James is known for his unstoppable",
    "My favorite part of LeBron James' game is",
    "LeBron James excels at",
]

# %%
request = [
    {
        "prompt": "{} was developed by",
        "subject": "Mario Kart",
        "target_new": {
            "str": "Apple",
        },
    }
]

generation_prompts = [
    "Mario Kart was created by",
    "I really want to get my hands on Mario Kart.",
    "Mario Kart is",
    "Which company created Mario Kart?",
]

# %%
from google.colab import drive
import os
import shutil

# Mount Google Drive
drive.mount('/content/drive')

# Define the source and destination paths
source_dir = '/content/memit'
destination_dir = '/content/drive/MyDrive/memit_backup'

# Create the destination directory if it doesn't exist
os.makedirs(destination_dir, exist_ok=True)

# Copy the contents of the source directory to the destination directory
try:
    shutil.copytree(source_dir, destination_dir, dirs_exist_ok=True)
    print(f"Successfully copied {source_dir} to {destination_dir}")
except FileExistsError:
    print(f"Directory {destination_dir} already exists. Contents may have been merged.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Successfully copied /content/memit to /content/drive/MyDrive/memit_backup

# %%
import os

source_dir = '/content/memit'
print(f"Contents of {source_dir}:")
print(os.listdir(source_dir))
# Out:
# Contents of /content/memit:
# ['baselines', 'data', 'CITATION.cff', '.gitattributes', 'rome', 'README.md', 'hparams', 'memit', 'dsets', 'scripts', 'notebooks', '.gitignore', 'LICENSE', 'game_theory', 'results', 'scaling_curves.sh', 'util', 'zsre_evals.sh', 'experiments', '.git', 'globals.yml', 'memit_game_theory.zip']
